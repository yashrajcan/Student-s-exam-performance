# %%
import pandas as pd 
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data = pd.read_csv("exams.csv")
data.head()
# Out:
#    gender race/ethnicity parental level of education         lunch  \
# 0  female        group D                some college      standard
# 1    male        group D          associate's degree      standard
# 2  female        group D                some college  free/reduced
# 3    male        group B                some college  free/reduced
# 4  female        group D          associate's degree      standard
#
#   test preparation course  math score  reading score  writing score
# 0               completed          59             70             78
# 1                    none          96             93             87
# 2                    none          57             76             77
# 3                    none          70             70             63
# 4                    none          83             85             86

# %%
 data.shape
# Out:
# (1000, 8)

# %%
data.isnull().sum()
# Out:
# gender                         0
# race/ethnicity                 0
# parental level of education    0
# lunch                          0
# test preparation course        0
# math score                     0
# reading score                  0
# writing score                  0
# dtype: int64

# %%
data.dtypes
# Out:
# gender                         object
# race/ethnicity                 object
# parental level of education    object
# lunch                          object
# test preparation course        object
# math score                      int64
# reading score                   int64
# writing score                   int64
# dtype: object

# %%
data['gender'].value_counts()
# Out:
# male      508
# female    492
# Name: gender, dtype: int64

# %%
data['parental level of education'].value_counts()
# Out:
# some college          224
# high school           215
# associate's degree    204
# some high school      177
# bachelor's degree     105
# master's degree        75
# Name: parental level of education, dtype: int64

# %%
data['race/ethnicity'].value_counts()
# Out:
# group C    323
# group D    257
# group B    198
# group E    143
# group A     79
# Name: race/ethnicity, dtype: int64

# %%
data['lunch'].value_counts()
# Out:
# standard        660
# free/reduced    340
# Name: lunch, dtype: int64

# %%
data['test preparation course'].value_counts()
# Out:
# none         656
# completed    344
# Name: test preparation course, dtype: int64

# %%
data['total'] = data['math score'] + data['reading score'] + data['writing score']

# %%
data['average'] = data['total']/3

# %%
sns.displot(['math score'])

# %%
sns.displot(['reading score '])

# %%
sns.displot(['writing score'])

# %%
sns.displot(['average'])

# %%
sns.pairplot(data)

# %%
sns.barplot(x = data['race/ethnicity'], y = data['average'], alpha = 0.8)
# Out:
# <Axes: xlabel='race/ethnicity', ylabel='average'>

# %%
sns.barplot(x = data['parental level of education'], y = data['average'], alpha = 0.8)
# Out:
# <Axes: xlabel='parental level of education', ylabel='average'>

# %%
data['race/ethnicity'][data['average']>70]
# Out:
# 1      group D
# 4      group D
# 6      group E
# 8      group C
# 10     group B
#         ...
# 994    group B
# 995    group C
# 996    group C
# 997    group A
# 998    group E
# Name: race/ethnicity, Length: 492, dtype: object

# %%
data['parental level of education'][data['average'] == min(data['average'])]
# Out:
# 228    high school
# Name: parental level of education, dtype: object

# %%
data['parental level of education'][data['average'] == max(data['average'])]
# Out:
# 378    bachelor's degree
# 857    bachelor's degree
# Name: parental level of education, dtype: object

# %%
sns.barplot(x = data['test preparation course'] , y = data['average'])
# Out:
# <Axes: xlabel='test preparation course', ylabel='average'>

# %%
data['math_passstatus'] = np.where(data['math score'] < 40, 'F','P')

# %%
data['read_passstatus'] = np.where(data['reading score'] < 40, 'F','P')

# %%
data['write_passstatus'] = np.where(data['writing score'] < 40, 'F','P')

# %%
data.head()
# Out:
#    gender race/ethnicity parental level of education         lunch  \
# 0  female        group D                some college      standard
# 1    male        group D          associate's degree      standard
# 2  female        group D                some college  free/reduced
# 3    male        group B                some college  free/reduced
# 4  female        group D          associate's degree      standard
#
#   test preparation course  math score  reading score  writing score  total  \
# 0               completed          59             70             78    207
# 1                    none          96             93             87    276
# 2                    none          57             76             77    210
# 3                    none          70             70             63    203
# 4                    none          83             85             86    254
#
#      average math_passstatus read_passstatus write_passstatus
# 0  69.000000               P               P                P
# 1  92.000000               P               P                P
# 2  70.000000               P               P                P
# 3  67.666667               P               P                P
# 4  84.666667               P               P                P

# %%
data['math_passstatus'].value_counts()
# Out:
# P    959
# F     41
# Name: math_passstatus, dtype: int64

# %%
data['read_passstatus'].value_counts()
# Out:
# P    983
# F     17
# Name: read_passstatus, dtype: int64

# %%
data['write_passstatus'].value_counts()
# Out:
# P    976
# F     24
# Name: write_passstatus, dtype: int64
